# %%
import os
import csv
import re

def preprocess_tweets():
    input_folder = "original_tweets"
    output_folder = "preprocessed_tweets/step1"
    file_name = "indicator_tweets_push_factors_social_factors.csv"
    
    input_file_path = os.path.join(input_folder, file_name)
    output_file_name = file_name.replace(".csv", "_preprocessed1.csv")
    output_file_path = os.path.join(output_folder, output_file_name)

    os.makedirs(output_folder, exist_ok=True)

    url_with_lang_pattern = re.compile(r"https?://\S+,\w{2}$")

    with open(input_file_path, mode='r', encoding='utf-8') as infile, open(output_file_path, mode='w', encoding='utf-8', newline='') as outfile:
        reader = csv.DictReader(infile)
        writer = csv.writer(outfile)

        for row in reader:
            text = row["text"]

            if url_with_lang_pattern.search(text):
                continue

            writer.writerow([text])

if __name__ == "__main__":
    preprocess_tweets()

# %%
import os
import csv
import re

def preprocess_tweets_step2():
    input_folder = "preprocessed_tweets/step1"
    output_folder = "preprocessed_tweets/step2"
    file_name = "indicator_tweets_push_factors_social_factors_preprocessed1.csv"

    input_file_path = os.path.join(input_folder, file_name)
    output_file_name = file_name.replace("_preprocessed1", "_preprocessed2")
    output_file_path = os.path.join(output_folder, output_file_name)

    os.makedirs(output_folder, exist_ok=True)

    url_pattern = re.compile(r"https?://\S+")

    with open(input_file_path, mode='r', encoding='utf-8') as infile, open(output_file_path, mode='w', encoding='utf-8', newline='') as outfile:
        reader = csv.reader(infile)
        writer = csv.writer(outfile)

        for row in reader:
            text = row[0]

            cleaned_text = url_pattern.sub("", text).strip()

            writer.writerow([cleaned_text])

if __name__ == "__main__":
    preprocess_tweets_step2()

# %%
import os
import csv
import re
import emoji

def preprocess_tweets_step3():
    input_folder = "preprocessed_tweets/step2"
    output_folder = "preprocessed_tweets/step3"
    file_name = "indicator_tweets_push_factors_social_factors_preprocessed2.csv"

    input_file_path = os.path.join(input_folder, file_name)
    output_file_name = file_name.replace("_preprocessed2", "_preprocessed3")
    output_file_path = os.path.join(output_folder, output_file_name)

    os.makedirs(output_folder, exist_ok=True)

    def convert_emojis_to_text(text):
        return emoji.demojize(text, delimiters=(":", ":"))

    with open(input_file_path, mode='r', encoding='utf-8') as infile, open(output_file_path, mode='w', encoding='utf-8', newline='') as outfile:
        reader = csv.reader(infile)
        writer = csv.writer(outfile)

        for row in reader:
            text = row[0]
            converted_text = convert_emojis_to_text(text)

            if text != converted_text:
                print(f"Original: {text}")
                print(f"Converted: {converted_text}")

            writer.writerow([converted_text])

if __name__ == "__main__":
    preprocess_tweets_step3()
# Out:
# Original: <unk> and TGRT Main News 📌IBB investigative country agenda 📌Crime announcement. Who is the BDDK accusing of "damaging assets"? 34 years later. Historical developments on the border of hunger and poverty 📌Market discount announcement #how to be remembered
# Converted: <unk> and TGRT Main News :pushpin:IBB investigative country agenda :pushpin:Crime announcement. Who is the BDDK accusing of "damaging assets"? 34 years later. Historical developments on the border of hunger and poverty :pushpin:Market discount announcement #how to be remembered
# Original: They denounce the economic management of the Motril City Council (Granada) for lack of services 👉
# Converted: They denounce the economic management of the Motril City Council (Granada) for lack of services :backhand_index_pointing_right:
# Original: <unk> Pre-cooked at home calculator Tariff <unk>️Turkish-Labour hunger limit of 8 thousand 864 TL. The poverty line is 28 thousand 875 TL. Before entering the kitchen, the materials were calculated.
# Converted: <unk> Pre-cooked at home calculator Tariff <unk>Turkish-Labour hunger limit of 8 thousand 864 TL. The poverty line is 28 thousand 875 TL. Before entering the kitchen, the materials were calculated.
# Original: 🏙️ San Francisco is at the heart of America’s tech boom.
#
# Yet homelessness is rampant, drug use soaring and violent crime rising.
#
# 🎙️@StevenEdginton speaks to Michael Shellenberger to find out what is happening to America’s most progressive cities
# Converted: :cityscape: San Francisco is at the heart of America’s tech boom.
#
# Yet homelessness is rampant, drug use soaring and violent crime rising.
#
# :studio_microphone:@StevenEdginton speaks to Michael Shellenberger to find out what is happening to America’s most progressive cities
# Original: Laid back zookeeper isn't phased feeding hungry alligators
#
# 🎥: The Reptile Zoo
# Converted: Laid back zookeeper isn't phased feeding hungry alligators
#
# :movie_camera:: The Reptile Zoo
# Original: Love, fun, crime and more are on #Discovery+ <unk>Entertainment has no limits <unk>Don't miss all the exclusive shows on 👉
# Converted: Love, fun, crime and more are on #Discovery+ <unk>Entertainment has no limits <unk>Don't miss all the exclusive shows on :backhand_index_pointing_right:
# Original: 🚨 Ukrainian zoo animals at risk of starvation as food supplies run out
# Converted: :police_car_light: Ukrainian zoo animals at risk of starvation as food supplies run out
# Original: ▶️An arrested person during a protest against a homelessness in Donostia:
# Converted: :play_button:An arrested person during a protest against a homelessness in Donostia:
# Original: 🔴 In Marioupol, local authorities are now talking about famine and accusing Russian forces of carrying out mass deportations of Ukrainians to #Russia Follow us directly #Ukraine <unk>️
# Converted: :red_circle: In Marioupol, local authorities are now talking about famine and accusing Russian forces of carrying out mass deportations of Ukrainians to #Russia Follow us directly #Ukraine <unk>
# Original: 🔴 In England, 800,000 children in poverty are excluded from receiving free school lunches. That’s children who are desperately hungry and in many cases scared, upset and ashamed.
#
# Sign petition ➡️
#
# Write to MP ➡️
#
# #FeedTheFuture
# Converted: :red_circle: In England, 800,000 children in poverty are excluded from receiving free school lunches. That’s children who are desperately hungry and in many cases scared, upset and ashamed.
#
# Sign petition :right_arrow:
#
# Write to MP :right_arrow:
#
# #FeedTheFuture
# Original: Who's hungry? 🍔🌱
# Converted: Who's hungry? :hamburger::seedling:
# Original: The poverty line has increased 34 percent in two months 📌 The hunger limit has reached 4 thousand 131 lira 📌 Minimum wage 4 thousand 253 lira
# Converted: The poverty line has increased 34 percent in two months :pushpin: The hunger limit has reached 4 thousand 131 lira :pushpin: Minimum wage 4 thousand 253 lira
# Original: <unk>️Fatma ÇELİK wrote: 📌"While the GOP defines the hunger limit as 4,152 TL, the poverty limit as 15,000 TL, according to the principle of social state, the main goal of political power should not be to condemn anyone to live below the poverty limit".
# Converted: <unk>Fatma ÇELİK wrote: :pushpin:"While the GOP defines the hunger limit as 4,152 TL, the poverty limit as 15,000 TL, according to the principle of social state, the main goal of political power should not be to condemn anyone to live below the poverty limit".
# Original: 📌 Great Britain, a former colony struggling with hunger and famine, has given Zimbabwe this benefit: 📌 "If the cattle eat, the hunger will end" <unk> Instead of agriculture and livestock, they invest in insects
# Converted: :pushpin: Great Britain, a former colony struggling with hunger and famine, has given Zimbabwe this benefit: :pushpin: "If the cattle eat, the hunger will end" <unk> Instead of agriculture and livestock, they invest in insects
# Original: 🔴 For today's subscribers only, Merida is more hungry
# Converted: :red_circle: For today's subscribers only, Merida is more hungry
# Original: <unk> #Vosges: review the police exercise at a crime scene in Xonrupt-Longemer <unk>️
# Converted: <unk> #Vosges: review the police exercise at a crime scene in Xonrupt-Longemer <unk>
# Original: For the first time, the Atlantic Alliance recognises the southern flank as one of the regions of greatest concern. There is hunger, terrorism and poverty ✍️For
# Converted: For the first time, the Atlantic Alliance recognises the southern flank as one of the regions of greatest concern. There is hunger, terrorism and poverty :writing_hand:For
# Original: 🗣️ "Trauma-related support should be part of any solution to ending homelessness."
# Converted: :speaking_head: "Trauma-related support should be part of any solution to ending homelessness."
# Original: <unk> The areas most affected by drought are the poorest. The Chabab movement has a strong presence. Aid cannot be sent without their consent. In Somalia, drought and conflict united for another famine 👇
# Converted: <unk> The areas most affected by drought are the poorest. The Chabab movement has a strong presence. Aid cannot be sent without their consent. In Somalia, drought and conflict united for another famine :backhand_index_pointing_down:
# Original: #Poverty imprisoned #Crime driven by socio-economic circumstances or the inability to face fines is sending many people to detention centres and defenselessness ✍️ and Vicent Almela
# Converted: #Poverty imprisoned #Crime driven by socio-economic circumstances or the inability to face fines is sending many people to detention centres and defenselessness :writing_hand: and Vicent Almela
# Original: They are aiming to tackle fuel poverty⛽
# Converted: They are aiming to tackle fuel poverty:fuel_pump:
# Original: <unk> Real Nazis in the black novel of the moment ➡ 'The demons of the Reich' elevates Fabiano Massimi to the height of great authors of 'Nazi crime'
# Converted: <unk> Real Nazis in the black novel of the moment :right_arrow: 'The demons of the Reich' elevates Fabiano Massimi to the height of great authors of 'Nazi crime'
# Original: Homelessness and homelessness: It is a problem that is particularly dramatic in the cold winter months, even in the economically strong Germany. The new German Ampel government wants to change that now, reports ▶️
# Converted: Homelessness and homelessness: It is a problem that is particularly dramatic in the cold winter months, even in the economically strong Germany. The new German Ampel government wants to change that now, reports :play_button:
# Original: <unk>️<unk>️ Foreign Minister #Ukraine<unk>: We have decided to deliver food exports to Africa and other regions through two open roads to save millions of hungry people. Russia is putting millions at risk of starvation by closing our ports. Russia must end its blockade to resume free exports
# Converted: <unk><unk> Foreign Minister #Ukraine<unk>: We have decided to deliver food exports to Africa and other regions through two open roads to save millions of hungry people. Russia is putting millions at risk of starvation by closing our ports. Russia must end its blockade to resume free exports
# Original: 🔴A woman obsessed with 'true crime' documentaries kills and dismembers a stranger <unk>out of curiosity<unk>
# Converted: :red_circle:A woman obsessed with 'true crime' documentaries kills and dismembers a stranger <unk>out of curiosity<unk>
# Original: 🔴The UN sends $40 million in cash each month to Afghanistan in a plane Nearly half the Afghan population goes hungry and six million are on the brink of starvation 👇
# Converted: :red_circle:The UN sends $40 million in cash each month to Afghanistan in a plane Nearly half the Afghan population goes hungry and six million are on the brink of starvation :backhand_index_pointing_down:
# Original: 🔴<unk> Jacqueline Savage: recounting the backstage of her presidential grace in the podcast <unk> Voices of Crime <unk>, see this episode here: <unk>
# Converted: :red_circle:<unk> Jacqueline Savage: recounting the backstage of her presidential grace in the podcast <unk> Voices of Crime <unk>, see this episode here: <unk>

# %%
import os
import csv
import ftfy
import unicodedata

def preprocess_tweets_step4():
    input_folder = "preprocessed_tweets/step3"
    output_folder = "preprocessed_tweets/step4"
    file_name = "indicator_tweets_push_factors_social_factors_preprocessed3.csv"

    input_file_path = os.path.join(input_folder, file_name)
    output_file_name = file_name.replace("_preprocessed3", "_preprocessed4")
    output_file_path = os.path.join(output_folder, output_file_name)

    os.makedirs(output_folder, exist_ok=True)

    def fix_encoding(text):
        text = ftfy.fix_text(text)
        text = unicodedata.normalize('NFC', text)
        return text.strip()

    with open(input_file_path, mode='r', encoding='utf-8') as infile, \
         open(output_file_path, mode='w', encoding='utf-8', newline='') as outfile:

        reader = csv.reader(infile)
        writer = csv.writer(outfile)

        for row in reader:
            original_text = row[0]
            cleaned_text = fix_encoding(original_text)

            if original_text != cleaned_text:
                print("Original:", original_text)
                print("Cleaned:", cleaned_text)

            writer.writerow([cleaned_text])

if __name__ == "__main__":
    preprocess_tweets_step4()
# Out:
# Original: Ukraine war is causing ‘famine in East Africa’
# Cleaned: Ukraine war is causing 'famine in East Africa'
# Original: Pragya Thakur says headscarves only worn by women ‘unsafe in homes’ amid #hijab row
# Cleaned: Pragya Thakur says headscarves only worn by women 'unsafe in homes' amid #hijab row
# Original: Dear Nadhim Zahawi, the Tories vowed to ‘eradicate illiteracy’ years ago. What went wrong? | Michael Rosen
# Cleaned: Dear Nadhim Zahawi, the Tories vowed to 'eradicate illiteracy' years ago. What went wrong? | Michael Rosen
# Original: In “Hungry Ghosts”, spectres of Trinidad’s past haunt the island
# Cleaned: In "Hungry Ghosts", spectres of Trinidad's past haunt the island
# Original: Poland’s poverty-busting pandemic - explained #InnovationActionChange
# Cleaned: Poland's poverty-busting pandemic - explained #InnovationActionChange
# Original: :cityscape: San Francisco is at the heart of America’s tech boom.
#
# Yet homelessness is rampant, drug use soaring and violent crime rising.
#
# :studio_microphone:@StevenEdginton speaks to Michael Shellenberger to find out what is happening to America’s most progressive cities
# Cleaned: :cityscape: San Francisco is at the heart of America's tech boom.
#
# Yet homelessness is rampant, drug use soaring and violent crime rising.
#
# :studio_microphone:@StevenEdginton speaks to Michael Shellenberger to find out what is happening to America's most progressive cities
# Original: Child refugees were ‘dumped’ in unsafe hotel, claims Brighton council
# Cleaned: Child refugees were 'dumped' in unsafe hotel, claims Brighton council
# Original: Adrien Brody reflects on his ‘starvation diet’ for The Pianist: ‘I got sick’
# Cleaned: Adrien Brody reflects on his 'starvation diet' for The Pianist: 'I got sick'
# Original: Editor’s letter: No child should go to school hungry – we’re making change happen
# Cleaned: Editor's letter: No child should go to school hungry – we're making change happen
# Original: North Korea 10 years on: Kim’s ‘war on young people’ and large scale starvation exposed
# Cleaned: North Korea 10 years on: Kim's 'war on young people' and large scale starvation exposed
# Original: Ukraine war is causing ‘famine in East Africa’
# Cleaned: Ukraine war is causing 'famine in East Africa'
# Original: Unsafe at the top: China’s anti-graft drive targets billionaires and bankers
# Cleaned: Unsafe at the top: China's anti-graft drive targets billionaires and bankers
# Original: Asylum seekers threatened with Rwanda deportation ‘stage hunger strike’
# Cleaned: Asylum seekers threatened with Rwanda deportation 'stage hunger strike'
# Original: :red_circle: In England, 800,000 children in poverty are excluded from receiving free school lunches. That’s children who are desperately hungry and in many cases scared, upset and ashamed.
#
# Sign petition :right_arrow:
#
# Write to MP :right_arrow:
#
# #FeedTheFuture
# Cleaned: :red_circle: In England, 800,000 children in poverty are excluded from receiving free school lunches. That's children who are desperately hungry and in many cases scared, upset and ashamed.
#
# Sign petition :right_arrow:
#
# Write to MP :right_arrow:
#
# #FeedTheFuture
# Original: Hungry grizzly bear steals fish from back of worker’s lorry
# Cleaned: Hungry grizzly bear steals fish from back of worker's lorry
# Original: Starving to death: Somalia’s worst drought in decades raises fears of famine
# Cleaned: Starving to death: Somalia's worst drought in decades raises fears of famine
# Original: Ancestor’s Irish famine role could merit compensation, says Laura Trevelyan
# Cleaned: Ancestor's Irish famine role could merit compensation, says Laura Trevelyan
# Original: ‘We all want to leave’: poverty, not crime, fuels the urge to flee Albania
# Cleaned: 'We all want to leave': poverty, not crime, fuels the urge to flee Albania
# Original: ‘Heat banks’, targeted payments and anti-poverty strategies
# Cleaned: 'Heat banks', targeted payments and anti-poverty strategies
# Original: Hungry driver gets Nando’s delivered to her car while queuing at petrol station
# Cleaned: Hungry driver gets Nando's delivered to her car while queuing at petrol station
# Original: ‘On the brink’: drought and politics leave Afghans fighting famine
# Cleaned: 'On the brink': drought and politics leave Afghans fighting famine
# Original: Coroner wants bassinets banned in childcare centres after baby’s death at ‘unsafe’ Sydney facility
# Cleaned: Coroner wants bassinets banned in childcare centres after baby's death at 'unsafe' Sydney facility
# Original: The UN’s multidimensional-poverty index uses ten indicators that measure education, health and sanitation
# Cleaned: The UN's multidimensional-poverty index uses ten indicators that measure education, health and sanitation
# Original: Norfolk police urges women to ‘challenge officers if they feel unsafe’
# Cleaned: Norfolk police urges women to 'challenge officers if they feel unsafe'
# Original: Parent felt ‘dirty and unsafe’ after visiting #Eastbourne pool
# Cleaned: Parent felt 'dirty and unsafe' after visiting #Eastbourne pool
# Original: Nearly half of women ‘feel unsafe using public transport alone after dark’
# Cleaned: Nearly half of women 'feel unsafe using public transport alone after dark'
# Original: With new research revealing 300,000 households could be forced into homelessness next year, @crisis_uk unveiled a hyper-real sculpture of a person experiencing homelessness at King’s Cross this morning, making homelessness 'impossible to ignore'
# Cleaned: With new research revealing 300,000 households could be forced into homelessness next year, @crisis_uk unveiled a hyper-real sculpture of a person experiencing homelessness at King's Cross this morning, making homelessness 'impossible to ignore'
# Original: Rashford calls on MPs to back recommendations to end the ‘child hunger pandemic’  #Rashford #Poverty #UniversalCredit
# Cleaned: Rashford calls on MPs to back recommendations to end the 'child hunger pandemic'  #Rashford #Poverty #UniversalCredit
# Original: ‘I’ve never seen so much vitriol’: activist Paul Boden on America’s homelessness crisis
# Cleaned: 'I've never seen so much vitriol': activist Paul Boden on America's homelessness crisis
# Original: Brazil’s new president wants to reduce the number of hungry people
# Cleaned: Brazil's new president wants to reduce the number of hungry people
# Original: Opinion: Children in our schools aren’t just hungry – they’re sad, scared and ashamed
# Cleaned: Opinion: Children in our schools aren't just hungry – they're sad, scared and ashamed
# Original: Nazanin Zaghari Ratcliffe’s husband vows to continue hunger strike
# Cleaned: Nazanin Zaghari Ratcliffe's husband vows to continue hunger strike
